# %% [markdown]
# # tuple -> (1,2,"misheal")
# # dict -> {"age" : 17, "school" : "man-dem", "scores" : [1,2,3,4]} it is a key:value
# # list -> [1,2,"mishael"]
# # integer -> 15
# # float -> 14.2
# # string -> "mishael", "18", 'phil'

# %%
age = 18

if age >= 17 :
    print("Give alcohol")
else: 
    print("No alcohol")
# Out:
# Give alcohol

# %%
# check if a number is even or odd number, if even, print even, if odd then print odd

number = 25
n = number % 2
if n == 0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
number = 30
n = number % 5

if n == 0:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
score = 45
if score >= 45 :
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
#LOOPS
for x in range(1,11):
    if x % 2 == 0:
        print(x)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for x in range (1,101):
    if  x /  >= 1:
        print(x)
# Out:
#   Cell In[26], line 2
#     if  x /  >= 1:
#              ^
# SyntaxError: invalid syntax

# %%
b = 7
if b <= 1:
    print("not a prime number")
for x in range(2, b):
    if b % x == 0:
        print("not a prime number :", x)
    else:
        print("prime number::", x)

# %%
amount = int(input("Amount"))
balance = 2000 
if balance > amount:
    new_balance = balance - amount
    print(new_balance)
else:
    print("insufficient balance")
# Out:
# 1934

# %%
"""  
Build a program that allows a user to login into the system, you need to set a default password, 
and then ask a user to re-enter the password, now use the password the user entered  to compare the default password you set.
if the user password doen't match the default password then ask user to re-enter his password. Ensure to allow user have 3 tries or attempts on login (i.e to re-enter password) before you tell them 
their account has been disabled or banned and then terminate the program.

Example:

default_passord = 'me'
password = input('enter your password')

then check if the two matches inside the while loop and if it matches, print "login successful" if not then after 3 tries terminate the program and print "Your account has been banned".

Note : Write your program outside this comment.

"""
# Out:
# '  \nBuild a program that allows a user to login into the system, you need to set a default password, \nand then ask a user to re-enter the password, now use the password the user entered  to compare the default password you set.\nif the user password doen\'t match the default password then ask user to re-enter his password. Ensure to allow user have 3 tries or attempts on login (i.e to re-enter password) before you tell them \ntheir account has been disabled or banned and then terminate the program.\n\nExample:\n\ndefault_passord = \'me\'\npassword = input(\'enter your password\')\n\nthen check if the two matches inside the while loop and if it matches, print "login successful" if not then after 3 tries terminate the program and print "Your account has been banned".\n\n'

# %%
# Out:
# account banned
# wrong password

# %%
num = 10
while num > 5:
    print("micheal", num)
    num = num - 1
# Out:
# micheal 10
# micheal 9
# micheal 8
# micheal 7
# micheal 6

# %%
count = 1
run = True
while count:
    age = input("what is your age")
    count = count +1
    if count > 4:
        print("you are banned!")
        break
    print("yes", count)
# Out:
# yes 2
# yes 3
# yes 4
# you are banned!

# %%
default_password = "me"
attempts = 3
password = input("enter your password:")
while attempts > 0:
    if password == default_password:
        print("login succesful")
        break
    else:
        attempts -= 1

        if attempts == 0:
            print("account banned")
            break
print("Wrong password.Try again.")
password = input("re-enter password:")
# Out:
# login succesful
# Wrong password.Try again.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#      13             break
#      14 print("Wrong password.Try again.")
# ---> 15 password = input("re-enter password:")
#
# File /opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
# ...
